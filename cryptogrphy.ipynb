# %%
from cryptography.fernet import Fernet
key= Fernet.generate_key()
print("encription key: ", key)

cipher = Fernet(key)

message = "Hello Roshan"
encrypted_message = cipher.encrypt(message.encode())
print("Encrypted message: ", encrypted_message)
decrypted_message = cipher.decrypt(encrypted_message).decode()
print("Decrypted message: ", decrypted_message)
# Out:
# encription key:  b'KpWXZBlhO98LAOYPzIfXxxXomK8C9vvKFxdj-nAd2Xo='
# Encrypted message:  b'gAAAAABo3rG7uQcfCeWpXjfA0eBzeDO2kGIe27aJ2YxzP89vjRCQaWXf8Pe3pi21g8E_CT0Y01elRGvHIDVgHAuSESWNlgxu6Q=='
# Decrypted message:  Hello Roshan
